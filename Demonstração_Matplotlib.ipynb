# %% [markdown]
# <a href="https://colab.research.google.com/github/william-alexandre/BigDataDeploy/blob/main/Demonstra%C3%A7%C3%A3o_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Demonstração Matplotlib
# ##Fundamentos de Big Data e Data Science

# %% [markdown]
# ###Utilização da Biblioteca Matplotlib

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib é uma biblioteca de software para criação de gráficos e visualizações de dados em geral, feita para e da linguagem de programação Python e sua extensão de matemática NumPy.

# %%
# Dados para o gráfico de linha
x = [1, 2, 3, 4, 5]

# %%
y = [2, 4, 6, 8, 10]

# %%
# Criar o gráfico de linha
plt.plot(x, y)

# %%
# Adicionar rótulos aos eixos x e y
plt.xlabel('Eixo X')
# Out:
# Text(0.5, 0, 'Eixo X')

# %%
plt.ylabel('Eixo Y')
# Out:
# Text(0, 0.5, 'Eixo Y')

# %%
# Adicionar título ao gráfico
plt.title('Gráfico de Linha Simples')
# Out:
# Text(0.5, 1.0, 'Gráfico de Linha Simples')

# %%
# Exibir o gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Dados para o gráfico de linha
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
# Criar o gráfico de linha
plt.plot(x, y)
# Adicionar rótulos aos eixos x e y
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
# Adicionar título ao gráfico
plt.title('Gráfico de Linha Simples')
# Out:
# Text(0.5, 1.0, 'Gráfico de Linha Simples')

# %%
import pandas as pd

df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],'radius': [2439.7, 6051.8, 6378.1]}, index=['Mercury', 'Venus', 'Earth'])

print(df)
plot = df.plot.pie(y='radius', figsize=(5, 5))
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
df = pd.DataFrame({'pig': [20, 18, 489, 675, 1776],'horse': [4, 25, 281, 600, 1900]}, index=[1990, 1997, 2003, 2009, 2014])
lines = df.plot.line()

# %%
df = pd.DataFrame( np.random.randint(1, 7, 6000), columns = ['one'])
df['two'] = df['one'] + np.random.randint(1, 7, 6000)
ax = df.plot.hist(bins=12, alpha=0.5)

# %%
https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html
# Out:
#   File "<ipython-input-3-28497eb57d1b>", line 1
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html
#           ^
# SyntaxError: invalid syntax
