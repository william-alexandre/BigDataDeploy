# %% [markdown]
# <a href="https://colab.research.google.com/github/william-alexandre/BigDataDeploy/blob/main/Demonstra%C3%A7%C3%A3o_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Demonstração Pandas
# ###Fundamentos de Big Data e Data Science

# %% [markdown]
# #Importar Bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Series (observe o índice do lado esquerdo)

# %%
s1=pd.Series([1,2,-5,0])

# %%
s1
# Out:
# 0    1
# 1    2
# 2   -5
# 3    0
# dtype: int64

# %%
s1.values
# Out:
# array([ 1,  2, -5,  0])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s1
# Out:
# 0    1
# 1    2
# 2   -5
# 3    0
# dtype: int64

# %%
s2=pd.Series([1,2,-5,0], index=['a','b', 'c', 'd'])

# %%
s2
# Out:
# a    1
# b    2
# c   -5
# d    0
# dtype: int64

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s2['a']=1000

# %%
s2
# Out:
# a    1000
# b       2
# c      -5
# d       0
# dtype: int64

# %% [markdown]
# #Comparação

# %%
s2[s2>0]
# Out:
# a    1000
# b       2
# dtype: int64

# %% [markdown]
# #Algebra

# %%
s3 = s2*2

# %%
s3
# Out:
# a    2000
# b       4
# c     -10
# d       0
# dtype: int64

# %%
s2
# Out:
# a    1000
# b       2
# c      -5
# d       0
# dtype: int64

# %%
s2[s2.isnull()] = 0

# %% [markdown]
# #Dataframe

# %% [markdown]
# #Criar Dataframe

# %%
dados={'estado':['SP', 'MG','PR','SP','MG','PR'],
       'ano':[2019, 2019,2019, 2020,2020,2020],
       'pop':[45.9, 21.2,16.9,46.6,21.4,17.3]}
df1=pd.DataFrame(dados)

# %%
print(dados)
# Out:
# {'estado': ['SP', 'MG', 'PR', 'SP', 'MG', 'PR'], 'ano': [2019, 2019, 2019, 2020, 2020, 2020], 'pop': [45.9, 21.2, 16.9, 46.6, 21.4, 17.3]}

# %%
df1
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9
# 3     SP  2020  46.6
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.head(3)
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9

# %% [markdown]
# #Visualizar partes Dataframe

# %%
df1.tail(2)
# Out:
#   estado   ano   pop
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.sample(2)
# Out:
#   estado   ano   pop
# 2     PR  2019  16.9
# 3     SP  2020  46.6

# %% [markdown]
# #Novo DF a partir o anterior (veja as colunas)

# %%
df2=pd.DataFrame(dados,columns=['ano', 'pop','estado'])

# %%
df2
# Out:
#     ano   pop estado
# 0  2019  45.9     SP
# 1  2019  21.2     MG
# 2  2019  16.9     PR
# 3  2020  46.6     SP
# 4  2020  21.4     MG
# 5  2020  17.3     PR

# %% [markdown]
# #Observar DF

# %%
df2['pop']
# Out:
# 0    45.9
# 1    21.2
# 2    16.9
# 3    46.6
# 4    21.4
# 5    17.3
# Name: pop, dtype: float64

# %%
s7=pd.Series(df2['pop'])

# %%
s7
# Out:
# 0    45.9
# 1    21.2
# 2    16.9
# 3    46.6
# 4    21.4
# 5    17.3
# Name: pop, dtype: float64

# %%
s7[s7>21]
# Out:
# 0    45.9
# 1    21.2
# 3    46.6
# 4    21.4
# Name: pop, dtype: float64

# %%
df2.estado
# Out:
# 0    SP
# 1    MG
# 2    PR
# 3    SP
# 4    MG
# 5    PR
# Name: estado, dtype: object

# %%
df2.dtypes
# Out:
# ano         int64
# pop       float64
# estado     object
# dtype: object

# %% [markdown]
# #Atribuir Valores

# %%
df2['estimativa']= df2['pop'] * 3

# %%
df2
# Out:
#     ano   pop estado  estimativa
# 0  2019  45.9     SP       137.7
# 1  2019  21.2     MG        63.6
# 2  2019  16.9     PR        50.7
# 3  2020  46.6     SP       139.8
# 4  2020  21.4     MG        64.2
# 5  2020  17.3     PR        51.9

# %%
df2['estimativa']=np.arange(6)

# %%
df2
# Out:
#     ano   pop estado  estimativa
# 0  2019  45.9     SP           0
# 1  2019  21.2     MG           1
# 2  2019  16.9     PR           2
# 3  2020  46.6     SP           3
# 4  2020  21.4     MG           4
# 5  2020  17.3     PR           5

# %%
df3=df2

# %%
df3
# Out:
#     ano   pop estado  estimativa
# 0  2019  45.9     SP           0
# 1  2019  21.2     MG           1
# 2  2019  16.9     PR           2
# 3  2020  46.6     SP           3
# 4  2020  21.4     MG           4
# 5  2020  17.3     PR           5

# %%
df3=df2['ano']

# %%
df3
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2020
# 4    2020
# 5    2020
# Name: ano, dtype: int64

# %%
df2['Não Paraná']= df2.estado != 'PR'

# %%
df2
# Out:
#     ano   pop estado  estimativa  Não Paraná
# 0  2019  45.9     SP           0        True
# 1  2019  21.2     MG           1        True
# 2  2019  16.9     PR           2       False
# 3  2020  46.6     SP           3        True
# 4  2020  21.4     MG           4        True
# 5  2020  17.3     PR           5       False

# %% [markdown]
# #Excluir Coluna

# %%
del df2['Não Paraná']

# %%
df2
# Out:
#     ano   pop estado  estimativa
# 0  2019  45.9     SP           0
# 1  2019  21.2     MG           1
# 2  2019  16.9     PR           2
# 3  2020  46.6     SP           3
# 4  2020  21.4     MG           4
# 5  2020  17.3     PR           5

# %% [markdown]
# #Entender o DataFrame

# %%
df2.shape
# Out:
# (6, 4)

# %%
df2.shape[1]
# Out:
# 4

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df2.columns
# Out:
# Index(['ano', 'pop', 'estado', 'estimativa'], dtype='object')

# %%
df2.count()
# Out:
# ano           6
# pop           6
# estado        6
# estimativa    6
# dtype: int64

# %% [markdown]
# #Alterar Informação das Colunas

# %%
df2.columns=['Ano','Pop','Estado','estimativa']

# %%
df2
# Out:
#     Ano   Pop Estado  estimativa
# 0  2019  45.9     SP           0
# 1  2019  21.2     MG           1
# 2  2019  16.9     PR           2
# 3  2020  46.6     SP           3
# 4  2020  21.4     MG           4
# 5  2020  17.3     PR           5

# %% [markdown]
# #Analisar o DataFrame

# %%
df2.describe(include='all')
# Out:
#                 Ano        Pop Estado  estimativa
# count      6.000000   6.000000      6    6.000000
# unique          NaN        NaN      3         NaN
# top             NaN        NaN     SP         NaN
# freq            NaN        NaN      2         NaN
# mean    2019.500000  28.216667    NaN    2.500000
# std        0.547723  14.096725    NaN    1.870829
# min     2019.000000  16.900000    NaN    0.000000
# 25%     2019.000000  18.275000    NaN    1.250000
# 50%     2019.500000  21.300000    NaN    2.500000
# 75%     2020.000000  39.775000    NaN    3.750000
# max     2020.000000  46.600000    NaN    5.000000

# %% [markdown]
# #Alterar valores e  consultar dados

# %%
df2['Ano']=df2['Ano']+2

# %%
df2
# Out:
#     Ano   Pop Estado  estimativa
# 0  2023  45.9     SP           0
# 1  2023  21.2     MG           1
# 2  2023  16.9     PR           2
# 3  2024  46.6     SP           3
# 4  2024  21.4     MG           4
# 5  2024  17.3     PR           5

# %%
df2[df2['Ano']>2021]
# Out:
#     Ano   Pop Estado  estimativa
# 0  2023  45.9     SP           0
# 1  2023  21.2     MG           1
# 2  2023  16.9     PR           2
# 3  2024  46.6     SP           3
# 4  2024  21.4     MG           4
# 5  2024  17.3     PR           5

# %%
df4=df2[df2['Ano']>2021]

# %%
df4
# Out:
#     Ano   Pop Estado  estimativa
# 0  2023  45.9     SP           0
# 1  2023  21.2     MG           1
# 2  2023  16.9     PR           2
# 3  2024  46.6     SP           3
# 4  2024  21.4     MG           4
# 5  2024  17.3     PR           5

# %% [markdown]
# #Excluir Colunas

# %%
df4.drop('Ano', axis='columns')
# Out:
#     Pop Estado  estimativa
# 0  45.9     SP           0
# 1  21.2     MG           1
# 2  16.9     PR           2
# 3  46.6     SP           3
# 4  21.4     MG           4
# 5  17.3     PR           5

# %%
df4
# Out:
#     Ano   Pop Estado  estimativa
# 0  2023  45.9     SP           0
# 1  2023  21.2     MG           1
# 2  2023  16.9     PR           2
# 3  2024  46.6     SP           3
# 4  2024  21.4     MG           4
# 5  2024  17.3     PR           5

# %%
df4
# Out:
#     Ano   Pop Estado  estimativa
# 0  2023  45.9     SP           0
# 1  2023  21.2     MG           1
# 2  2023  16.9     PR           2
# 3  2024  46.6     SP           3
# 4  2024  21.4     MG           4
# 5  2024  17.3     PR           5

# %%
df2
# Out:
#     Ano   Pop Estado  estimativa
# 0  2023  45.9     SP           0
# 1  2023  21.2     MG           1
# 2  2023  16.9     PR           2
# 3  2024  46.6     SP           3
# 4  2024  21.4     MG           4
# 5  2024  17.3     PR           5

# %%
df2.drop('Ano', axis='columns', inplace=True)

# %%
df2
# Out:
#     Pop Estado  estimativa
# 0  45.9     SP           0
# 1  21.2     MG           1
# 2  16.9     PR           2
# 3  46.6     SP           3
# 4  21.4     MG           4
# 5  17.3     PR           5

# %% [markdown]
# #Excluir Linhas

# %%
df2.drop([0,1])
# Out:
#     Pop Estado  estimativa
# 2  16.9     PR           2
# 3  46.6     SP           3
# 4  21.4     MG           4
# 5  17.3     PR           5

# %%
df2
# Out:
#     Pop Estado  estimativa
# 2  16.9     PR           2
# 3  46.6     SP           3
# 4  21.4     MG           4
# 5  17.3     PR           5

# %% [markdown]
# ###Observe a propagação na exclusão definitiva

# %%
dflinhas=df2

# %%
dflinhas.drop([0,1],inplace=True)

# %%
dflinhas
# Out:
#     Pop Estado  estimativa
# 2  16.9     PR           2
# 3  46.6     SP           3
# 4  21.4     MG           4
# 5  17.3     PR           5

# %%
df2
# Out:
#     ano   pop estado
# 2  2019  16.9     PR
# 3  2020  46.6     SP
# 4  2020  21.4     MG
# 5  2020  17.3     PR

# %% [markdown]
# #Ver Dados de linhas

# %%
df2.iloc[2]
# Out:
# ano       2020
# pop       21.4
# estado      MG
# Name: 4, dtype: object

# %%
df2.iloc[1:4]
# Out:
#     ano   pop estado
# 3  2020  46.6     SP
# 4  2020  21.4     MG
# 5  2020  17.3     PR

# %%
df2.iloc[1:3,[1,2]]
# Out:
#     pop estado
# 3  46.6     SP
# 4  21.4     MG

# %%
df2
# Out:
#     ano   pop estado
# 2  2019  16.9     PR
# 3  2020  46.6     SP
# 4  2020  21.4     MG
# 5  2020  17.3     PR
